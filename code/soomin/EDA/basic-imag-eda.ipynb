# %%
from basic_image_eda import BasicImageEDA

# %%
if __name__ == "__main__":  # for multiprocessing
    data_dir = "/opt/ml/input/data"
    BasicImageEDA.explore(data_dir)

    # or

    extensions = ['png', 'jpg', 'jpeg']
    threads = 0
    dimension_plot = True
    channel_hist = True
    nonzero = False
    hw_division_factor = 1.0

    BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
# found 100000 images.
#   0%|          | 23/100000 [00:00<07:25, 224.17it/s]
# Using 8 threads. (max:8)
# 100%|██████████| 100000/100000 [08:56<00:00, 186.55it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  100000
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  20
# max height                               |  10020
# mean height                              |  333.0981
# median height                            |  255
#
# min width                                |  35
# max width                                |  11810
# mean width                               |  1309.31791
# median width                             |  1012
#
# mean height/width ratio                  |  0.25440582264699946
# median height/width ratio                |  0.2519762845849802
# recommended input size(by mean)          |  [ 336 1312] (h x w, multiples of 8)
# recommended input size(by mean)          |  [ 336 1312] (h x w, multiples of 16)
# recommended input size(by mean)          |  [ 320 1312] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.62822465 0.61521363 0.58638965]
# channel std(0~1)                         |  [0.16683661 0.17118783 0.17762735]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 08 minutes 59 seconds
#
# found 100000 images.
#   0%|          | 10/100000 [00:00<18:42, 89.10it/s]
# Using 8 threads. (max:8)
# 100%|██████████| 100000/100000 [13:50<00:00, 120.41it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  100000
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['jpg']
#
# min height                               |  20
# max height                               |  10020
# mean height                              |  333.0981
# median height                            |  255
#
# min width                                |  35
# max width                                |  11810
# mean width                               |  1309.31791
# median width                             |  1012
#
# mean height/width ratio                  |  0.25440582264699946
# median height/width ratio                |  0.2519762845849802
# recommended input size(by mean)          |  [ 336 1312] (h x w, multiples of 8)
# recommended input size(by mean)          |  [ 336 1312] (h x w, multiples of 16)
# recommended input size(by mean)          |  [ 320 1312] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.62822465 0.61521355 0.58638965]
# channel std(0~1)                         |  [0.16683673 0.17118811 0.17762713]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 13 minutes 51 seconds
